# %% [markdown]
# OOPS

# %%
# Class is a blue print for creating objects. An object is an instance of a class.

class Car:
    pass                 #pass is a null statement - it does nothing when executed.
audi=Car()
bmw=Car()
print(type(audi))
# Out:
# <class '__main__.Car'>

# %%
## Instance Variable and Methods

class Dog:
    #Constructor (likhte using init)
      def __init__(self,name,age):    # self ki jagah kuch bhi use kr skte it is just for using instance allocation
            self.name=name
            self.age=age 

dog1=Dog('kalu',45)
print(type(dog1))
print(dog1.age)
# Out:
# <class '__main__.Dog'>
# 45

# %%
# Degine a  class with instance methods
class Dog:
    def __init__(self,name,age):    # self ki jagah kuch bhi use kr skte it is just for using instance allocation
            self.name=name
            self.age=age 
    
    def bark(self):              # using self here to access above name age in this fxn
          print(f"{self.name} says woof")
    
dog1=Dog("klair",4)
dog1.bark()
# Out:
# klair says woof

# %%
### MOdeling a Bank account 

class BankAccount:
    def __init__(self,owner,balance=0):
        self.owner=owner
        self.balance=balance
    
    def deposit(self,amount):
        self.balance+=amount
        print(f"{amount} is deposited. New balance is {self.balance}")

    def withdraw(self,amount):
        if self.balance<amount:
            print("Insufficient funds")
        else:
            self.balance-=amount
            print(f"{amount} is withdrawn New balance {self.balance}")

    def get_balance(self):
        return self.balance

## Create an account
account=BankAccount("trainu",5000) 
print(account.balance)

print(account.get_balance())
account.withdraw(100)
# Out:
# 5000
# 5000
# 100 is withdrawn New balance 4900
