# %% [markdown]
# Importing Modules in Python: Modules and Packages

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
print(sqrt(4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(sqrt(4))
#
# NameError: name 'sqrt' is not defined

# %%
# so to cure it we have to import the specific function from the module

from math import sqrt,pi
print(sqrt(4))
print(pi)
# Out:
# 2.0
# 3.141592653589793

# %% [markdown]
# ### Numpy
# it is used for array based operations

# %%
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# sometimes during creating virtual environment many of packages gets installed and more some neeed to be installed via terminal pip install numpy
# this will install in venv environment
#
# and (optional) add in requirements.txt for keep track
# so if u want install all in requirements.txt at once just go and run
# pip install -r requirements.txt

# %%
import numpy as np               # np is alias for numpy
np.array([1,2,3])
# Out:
# array([1, 2, 3])

# %%
from math import *        # imports all functions from math module

sqrt(25)
# Out:
# 5.0

# %% [markdown]
# # Using Custom Package module created by us

# %%
from package.maths import addition
addition(5, 10)
# Out:
# 15

# %%
# alter way
from package import maths
maths.addition(7, 3)
# Out:
# 10
