# %% [markdown]
# ## Streamlit
# it is an open source app framework for ML And DS projects.
# It allows u to create web applications for your ML and ds projects with simple python scripts

# %% [markdown]
# GO install streamlit first
