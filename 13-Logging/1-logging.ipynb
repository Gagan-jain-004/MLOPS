# %% [markdown]
# # Python Logging
# logging is a crucial aspect of applictn, providing way to track events,errors and operational info.
# Python built-in logging module offers a flexible framewrk for emitting log messages from Python programs.

# %%
import logging

# Configure the basic logging settings
logging.basicConfig(level=logging.DEBUG)

## log messages with different severity levels
logging.debug("This is a debug msg")
logging.info("This is an info msg")
logging.warning("This is a warning msg")
logging.error("This is an error msg")
logging.critical("This is a critical msg")
# Out:
# DEBUG:root:This is a debug msg
# INFO:root:This is an info msg
# WARNING:root:This is a warning msg
# ERROR:root:This is an error msg
# CRITICAL:root:This is a critical msg

# %% [markdown]
# # Log Levels
# default levels are:
#  - DEBUG: detailed information, only when dianosing problm
#  - INFO: Confirmation that things working as expected
#  - WARNING: unexpected happend or indicative of some prob in futr (eg: disk space low)
#  - ERROR: dut to some prob, software not able to perform well
#  - CRITICAL: A serious error

# %%
## configuring logging

import logging

# below v r updating basicConfig  so restart kernel from top bar as v executed previous so that's why

logging.basicConfig(
    filename='app.log',
    filemode='w',
    level=logging.DEBUG,
    format='%(asctime)s-%(name)s-%(levelname)s-%(message)s',
    datefmt='%Y-%m-%d %H:%M:%S' 
)

## log messages with different severity levels
logging.debug("This is a debug msg")
logging.info("This is an info msg")
logging.warning("This is a warning msg")
logging.error("This is an error msg")
logging.critical("This is a critical msg")

# %% [markdown]
# make logs folder then make logger.py and write your logging config
# then import in file u want like test.py  to use it
# and after running in terminal python test.py
# chk logs in  app.log
